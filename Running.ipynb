# %% [markdown]
# <a href="https://colab.research.google.com/github/vano04/CorridorKeyV2/blob/main/Running.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

# Load secrets from Colab's secret manager
os.environ['GITHUB'] = userdata.get('Github')
os.environ['HF_TOKEN'] = userdata.get('HF')

print("Environment variables GITHUB and HF_TOKEN have been set.")
# Out:
# Environment variables GITHUB and HF_TOKEN have been set.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://$GITHUB@github.com/vano04/CorridorKeyV2.git
# !mv CorridorKeyV2/* . && rm -rf CorridorKeyV2
# !git clone https://github.com/vano04/openexr
# !uv pip install torch torchvision torchao tqdm pyyaml pytest simplejson webdataset safetensors
# !uv pip install ./openexr
# Out:
# Cloning into 'CorridorKeyV2'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 134 (delta 59), reused 111 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 217.45 KiB | 10.87 MiB/s, done.
# Resolving deltas: 100% (59/59), done.
# Cloning into 'openexr'...
# remote: Enumerating objects: 27736, done.
# remote: Counting objects: 100% (559/559), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 27736 (delta 466), reused 346 (delta 346), pack-reused 27177 (from 3)
# Receiving objects: 100% (27736/27736), 61.19 MiB | 34.93 MiB/s, done.
# Resolving deltas: 100% (20071/20071), done.
# Using Python 3.12.13 environment at: /usr
# Resolved 43 packages in 373ms
# Prepared 2 packages in 14ms
# Installed 2 packages in 4ms
#  + braceexpand==0.1.7
#  + webdataset==1.0.2
# Using Python 3.12.13 environment at: /usr
# Resolved 2 packages in 1.32s
# Prepared 1 package in 18.74s
# Installed 1 package in 0.51ms
#  + openexr==4.0.0 (from file:///content/openexr)

# %%
# !PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True uv run python training.py --config configs/g4.yaml --output-dir drive/MyDrive/checkpoints/
# Out:
# Dataset module=CorridorKeyDataset.dataset mode=local root=CorridorKeyDataset modalities=('Input', 'FG', 'BG', 'Alpha') convert_to_float=True
# GPU augment enabled: CPU pipeline emits OpenEXR tile-ROI FG/BG/Alpha; spatial crop + photometric/sensor/codec augments + composite + coarse_alpha_init run on device after H2D.
# Trainable parameters: 46,459,654 / 46,459,654
# Optimizer: AdamW(fused=True, groups=1) default=46,459,654
# LR schedule: warmup=0, total=200000, base_lr=5.00e-06, min_lr_ratio=0.1
# Step accounting: dataloader_iters_per_epoch=5000, grad_accum_steps=1, optimizer_steps_per_epoch=5000
# Training inference mode: hybrid
# CUDA warmup skipped (train.cuda_warmup=false).
# epoch=000 iter=00020/05000 step=000020 lr=5.00e-06 alpha_l1=0.4703 fg_l1=0.3436 comp_l1=0.1384 alpha_lap=0.0131 alpha_band_l1=0.2855 alpha_band_lap=0.0472 temporal_alpha=0.0331 temporal_fg=0.0180 comp_random_bg=0.2242 spill_l1=0.6645 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.4640 green_bg_alpha_suppress_abs=0.4640 green_bg_pixels=0.1469 coarse_alpha_l1=0.4702 coarse_fg_l1=0.1143 native_alpha_delta_reg=0.0057 native_fg_delta_reg=0.0045 uncertainty=0.0655 quality_eval=0.0671 total=1.8935
# epoch=000 iter=00040/05000 step=000040 lr=5.00e-06 alpha_l1=0.3591 fg_l1=0.4708 comp_l1=0.0508 alpha_lap=0.0066 alpha_band_l1=0.2607 alpha_band_lap=0.0330 temporal_alpha=0.0047 temporal_fg=0.0009 comp_random_bg=0.1543 spill_l1=0.6685 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.3757 green_bg_alpha_suppress_abs=0.3757 green_bg_pixels=0.2715 coarse_alpha_l1=0.3596 coarse_fg_l1=0.1574 native_alpha_delta_reg=0.0066 native_fg_delta_reg=0.0061 uncertainty=0.2536 quality_eval=0.2021 total=1.7108
# epoch=000 iter=00060/05000 step=000060 lr=5.00e-06 alpha_l1=0.0770 fg_l1=1.1377 comp_l1=0.0209 alpha_lap=0.0028 alpha_band_l1=0.3884 alpha_band_lap=0.0344 temporal_alpha=0.0054 temporal_fg=0.0022 comp_random_bg=0.0290 spill_l1=0.7702 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0677 green_bg_alpha_suppress_abs=0.0677 green_bg_pixels=0.4366 coarse_alpha_l1=0.0776 coarse_fg_l1=0.3799 native_alpha_delta_reg=0.0051 native_fg_delta_reg=0.0054 uncertainty=0.6295 quality_eval=0.5729 total=1.9609
# epoch=000 iter=00080/05000 step=000080 lr=5.00e-06 alpha_l1=0.3893 fg_l1=0.0985 comp_l1=0.1229 alpha_lap=0.0125 alpha_band_l1=0.6377 alpha_band_lap=0.0730 temporal_alpha=0.0065 temporal_fg=0.0021 comp_random_bg=0.1890 spill_l1=0.4657 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0484 green_bg_alpha_suppress_abs=0.0484 green_bg_pixels=0.0106 coarse_alpha_l1=0.3909 coarse_fg_l1=0.0330 native_alpha_delta_reg=0.0069 native_fg_delta_reg=0.0048 uncertainty=0.5015 quality_eval=0.4565 total=1.4805
# epoch=000 iter=00100/05000 step=000100 lr=5.00e-06 alpha_l1=0.3368 fg_l1=0.2715 comp_l1=0.0885 alpha_lap=0.0082 alpha_band_l1=0.4769 alpha_band_lap=0.0194 temporal_alpha=0.1054 temporal_fg=0.0280 comp_random_bg=0.1400 spill_l1=0.7665 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0000 green_bg_alpha_suppress_abs=0.0000 green_bg_pixels=0.0000 coarse_alpha_l1=0.3369 coarse_fg_l1=0.0906 native_alpha_delta_reg=0.0041 native_fg_delta_reg=0.0037 uncertainty=0.3622 quality_eval=0.4047 total=1.4957
# epoch=000 iter=00120/05000 step=000120 lr=5.00e-06 alpha_l1=0.5392 fg_l1=0.1301 comp_l1=0.0973 alpha_lap=0.0107 alpha_band_l1=0.4043 alpha_band_lap=0.0155 temporal_alpha=0.1025 temporal_fg=0.0224 comp_random_bg=0.2567 spill_l1=0.6259 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.1310 green_bg_alpha_suppress_abs=0.1310 green_bg_pixels=0.0000 coarse_alpha_l1=0.5393 coarse_fg_l1=0.0435 native_alpha_delta_reg=0.0035 native_fg_delta_reg=0.0040 uncertainty=0.4795 quality_eval=0.4475 total=1.6965
# epoch=000 iter=00140/05000 step=000140 lr=5.00e-06 alpha_l1=0.0504 fg_l1=0.0000 comp_l1=0.0414 alpha_lap=0.0019 alpha_band_l1=0.0000 alpha_band_lap=0.0000 temporal_alpha=0.0015 temporal_fg=0.0000 comp_random_bg=0.0181 spill_l1=0.0000 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0500 green_bg_alpha_suppress_abs=0.0500 green_bg_pixels=0.0095 coarse_alpha_l1=0.0502 coarse_fg_l1=0.0000 native_alpha_delta_reg=0.0041 native_fg_delta_reg=0.0038 uncertainty=0.1560 quality_eval=0.2470 total=0.1907
# epoch=000 iter=00160/05000 step=000160 lr=5.00e-06 alpha_l1=0.2782 fg_l1=0.8622 comp_l1=0.0904 alpha_lap=0.0073 alpha_band_l1=0.4612 alpha_band_lap=0.0247 temporal_alpha=0.0591 temporal_fg=0.0472 comp_random_bg=0.1118 spill_l1=0.6560 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0586 green_bg_alpha_suppress_abs=0.0586 green_bg_pixels=0.0410 coarse_alpha_l1=0.2783 coarse_fg_l1=0.2875 native_alpha_delta_reg=0.0026 native_fg_delta_reg=0.0037 uncertainty=0.2513 quality_eval=0.2836 total=2.0123
# epoch=000 iter=00180/05000 step=000180 lr=5.00e-06 alpha_l1=0.2384 fg_l1=0.6509 comp_l1=0.0674 alpha_lap=0.0059 alpha_band_l1=0.4679 alpha_band_lap=0.0243 temporal_alpha=0.0477 temporal_fg=0.0336 comp_random_bg=0.1004 spill_l1=0.6703 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0563 green_bg_alpha_suppress_abs=0.0563 green_bg_pixels=0.1038 coarse_alpha_l1=0.2385 coarse_fg_l1=0.2171 native_alpha_delta_reg=0.0029 native_fg_delta_reg=0.0037 uncertainty=0.2037 quality_eval=0.2444 total=1.6837
# epoch=000 iter=00200/05000 step=000200 lr=5.00e-06 alpha_l1=0.3648 fg_l1=0.3906 comp_l1=0.1352 alpha_lap=0.0118 alpha_band_l1=0.6554 alpha_band_lap=0.0749 temporal_alpha=0.0270 temporal_fg=0.0251 comp_random_bg=0.1486 spill_l1=0.4555 green_fg_alpha=0.9880 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.9880 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0104 green_bg_alpha_suppress_abs=0.0104 green_bg_pixels=0.4668 coarse_alpha_l1=0.3651 coarse_fg_l1=0.1303 native_alpha_delta_reg=0.0051 native_fg_delta_reg=0.0044 uncertainty=0.2805 quality_eval=0.2865 total=1.8211
# epoch=000 iter=00220/05000 step=000220 lr=5.00e-06 alpha_l1=0.5431 fg_l1=0.2368 comp_l1=0.1377 alpha_lap=0.0120 alpha_band_l1=0.2885 alpha_band_lap=0.0204 temporal_alpha=0.1257 temporal_fg=0.0275 comp_random_bg=0.2131 spill_l1=0.8623 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.5827 green_bg_alpha_suppress_abs=0.5827 green_bg_pixels=0.0000 coarse_alpha_l1=0.5437 coarse_fg_l1=0.0791 native_alpha_delta_reg=0.0046 native_fg_delta_reg=0.0049 uncertainty=0.1813 quality_eval=0.2038 total=2.0317
# epoch=000 iter=00240/05000 step=000240 lr=5.00e-06 alpha_l1=0.3362 fg_l1=0.1642 comp_l1=0.0457 alpha_lap=0.0078 alpha_band_l1=0.3706 alpha_band_lap=0.0159 temporal_alpha=0.1439 temporal_fg=0.0252 comp_random_bg=0.1633 spill_l1=0.7758 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.1296 green_bg_alpha_suppress_abs=0.1296 green_bg_pixels=0.0498 coarse_alpha_l1=0.3362 coarse_fg_l1=0.0549 native_alpha_delta_reg=0.0026 native_fg_delta_reg=0.0043 uncertainty=0.2359 quality_eval=0.2463 total=1.3352
# epoch=000 iter=00260/05000 step=000260 lr=5.00e-06 alpha_l1=0.3380 fg_l1=0.1218 comp_l1=0.0389 alpha_lap=0.0159 alpha_band_l1=0.4106 alpha_band_lap=0.0633 temporal_alpha=0.0538 temporal_fg=0.0094 comp_random_bg=0.1549 spill_l1=0.7086 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0434 green_bg_alpha_suppress_abs=0.0434 green_bg_pixels=0.0542 coarse_alpha_l1=0.3381 coarse_fg_l1=0.0407 native_alpha_delta_reg=0.0039 native_fg_delta_reg=0.0041 uncertainty=0.2430 quality_eval=0.2523 total=1.2460
# epoch=000 iter=00280/05000 step=000280 lr=5.00e-06 alpha_l1=0.6082 fg_l1=0.6484 comp_l1=0.0789 alpha_lap=0.0116 alpha_band_l1=0.4200 alpha_band_lap=0.0218 temporal_alpha=0.0527 temporal_fg=0.0284 comp_random_bg=0.2500 spill_l1=1.1460 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0052 green_bg_alpha_suppress_abs=0.0052 green_bg_pixels=0.0000 coarse_alpha_l1=0.6083 coarse_fg_l1=0.2165 native_alpha_delta_reg=0.0032 native_fg_delta_reg=0.0041 uncertainty=0.4031 quality_eval=0.3913 total=2.4015
# epoch=000 iter=00300/05000 step=000300 lr=5.00e-06 alpha_l1=0.1129 fg_l1=0.4258 comp_l1=0.0944 alpha_lap=0.0052 alpha_band_l1=0.3390 alpha_band_lap=0.0294 temporal_alpha=0.0606 temporal_fg=0.0557 comp_random_bg=0.1101 spill_l1=0.7734 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.1332 green_bg_alpha_suppress_abs=0.1332 green_bg_pixels=0.4180 coarse_alpha_l1=0.1132 coarse_fg_l1=0.1423 native_alpha_delta_reg=0.0045 native_fg_delta_reg=0.0041 uncertainty=0.1180 quality_eval=0.1819 total=1.2722
# epoch=000 iter=00320/05000 step=000320 lr=5.00e-06 alpha_l1=0.1002 fg_l1=0.2682 comp_l1=0.0763 alpha_lap=0.0096 alpha_band_l1=0.4947 alpha_band_lap=0.0683 temporal_alpha=0.0200 temporal_fg=0.0213 comp_random_bg=0.0869 spill_l1=0.4171 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.0117 green_bg_alpha_suppress_abs=0.0117 green_bg_pixels=0.3711 coarse_alpha_l1=0.1005 coarse_fg_l1=0.0895 native_alpha_delta_reg=0.0061 native_fg_delta_reg=0.0039 uncertainty=0.1123 quality_eval=0.1766 total=0.9881
# epoch=000 iter=00340/05000 step=000340 lr=5.00e-06 alpha_l1=0.6498 fg_l1=0.2570 comp_l1=0.1128 alpha_lap=0.0132 alpha_band_l1=0.4264 alpha_band_lap=0.0217 temporal_alpha=0.1321 temporal_fg=0.0169 comp_random_bg=0.2440 spill_l1=0.3916 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.7632 green_bg_alpha_suppress_abs=0.7632 green_bg_pixels=0.0000 coarse_alpha_l1=0.6496 coarse_fg_l1=0.0858 native_alpha_delta_reg=0.0039 native_fg_delta_reg=0.0035 uncertainty=0.4675 quality_eval=0.4310 total=2.2928
# epoch=000 iter=00360/05000 step=000360 lr=5.00e-06 alpha_l1=0.4660 fg_l1=0.1597 comp_l1=0.0508 alpha_lap=0.0125 alpha_band_l1=0.4420 alpha_band_lap=0.0289 temporal_alpha=0.1530 temporal_fg=0.0222 comp_random_bg=0.2477 spill_l1=0.4016 green_fg_alpha=0.0000 green_fg_color=0.0000 green_fg_pixels=0.0000 green_fg_alpha_abs=0.0000 green_fg_color_abs=0.0000 green_bg_alpha_suppress=0.7263 green_bg_alpha_suppress_abs=0.7263 green_bg_pixels=0.0000 coarse_alpha_l1=0.4660 coarse_fg_l1=0.0533 native_alpha_delta_reg=0.0055 native_fg_delta_reg=0.0037 uncertainty=0.4256 quality_eval=0.4173 total=1.8457
# Epoch 1/40:   7% 360/5000 [14:06<3:01:56,  2.35s/it, lr=5.00e-06, step=360]
# Saving checkpoint: drive/MyDrive/checkpoints/checkpoint_epoch_000.pt
# Saved checkpoint: drive/MyDrive/checkpoints/checkpoint_epoch_000.pt
# [epoch 000] avg_total_loss=0.126197
# Epoch 2/40:   0% 4/5000 [00:46<9:59:44,  7.20s/it, lr=5.00e-06, step=364]
